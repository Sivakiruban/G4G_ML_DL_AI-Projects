# %% [markdown]
# # Creating a market analyst using AI agents

# %%
# !pip install crewai crewai-tools langchain-google-genai

# %%
import os
from crewai import Agent, Task, Crew, Process, LLM
from crewai_tools import SerperDevTool

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
import os

# %% [markdown]
# Initializing the Gemini model:

# %%
gemini_llm = LLM(
    model="gemini/gemini-2.5-flash",
    api_key=os.environ.get('GOOGLE_API_KEY')
)

# %% [markdown]
# Using the search tool: Serper
#
# (https://serper.dev/api-keys)

# %%
# Load the API key from Colab secrets
serper_api_key = os.environ.get('SERPER_API_KEY')


search_tool = SerperDevTool()

# %% [markdown]
# Researcher agent:

# %%
researcher = Agent(
  role='Market Researcher',
  goal='Find and analyze the latest trends in the AI industry',
  backstory="""You are an expert market researcher. You are skilled at
  finding the most relevant and up-to-date information on any given
  topic, and you are known for your ability to synthesize complex
  information into clear and concise summaries.""",
  verbose=True,
  allow_delegation=False,
  tools=[search_tool],
  llm=gemini_llm
)

# %% [markdown]
# Writer agent:

# %%
writer = Agent(
  role='Content Writer',
  goal='Write a compelling and engaging blog post about the latest AI trends',
  backstory="""You are a renowned content writer, known for your ability
  to create engaging and informative content. You have a knack for
  turning complex topics into easy-to-understand articles that
  resonate with a wide audience.""",
  verbose=True,
  allow_delegation=True,
  llm=gemini_llm
)

# %% [markdown]
# Creating the research and writing tasks:

# %%
research_task = Task(
  description="""Research the latest trends in the AI industry.
  Your research should focus on the most significant advancements,
  emerging technologies, and key players. The final output should be a
  detailed report with your findings.""",
  expected_output='A comprehensive report summarizing the latest AI trends.',
  agent=researcher
)

write_task = Task(
  description="""Write a blog post based on the research findings.
  The blog post should be engaging, informative, and accessible to a
  non-technical audience. It should highlight the key trends and their
  potential impact on the future.""",
  expected_output='A 500-word blog post on the latest AI trends.',
  agent=writer
)

# %% [markdown]
# Creating and kicking off the crew:

# %%
marketing_crew = Crew(
  agents=[researcher, writer],
  tasks=[research_task, write_task],
  process=Process.sequential,
  verbose=True
)

# %%
result = marketing_crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: b78a4d69-2839-4475-8350-1e7ff2d57a5f                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ...

# %%
# Define the filename
output_filename = "blog_post.md"

# Open the file in write mode ('w') and save the content
with open(output_filename, 'w', encoding='utf-8') as file:
    file.write(result.raw)

print(f"\n Blog post successfully saved to {output_filename}")
# Out:
#  Blog post successfully saved to blog_post.md

# %% [markdown]
# # Can you summarize the output in 30-40 lines?

# %%
# Creating a summarizer agent to summarize the blog post output

# %%
# Summarizer agent
summarizer = Agent(
  role='Content Summarizer',
  goal='Create a concise 30-40 line summary of the AI trends blog post',
  backstory="""You are an expert content summarizer with a talent for distilling 
  complex information into clear, concise summaries. You excel at capturing the 
  key points and main themes while maintaining readability and impact.""",
  verbose=True,
  allow_delegation=False,
  llm=gemini_llm
)

# %%
# Read the blog post content
with open('blog_post.md', 'r', encoding='utf-8') as file:
    blog_content = file.read()

print("Blog post content loaded successfully!")
print(f"Content length: {len(blog_content)} characters")
# Out:
# Blog post content loaded successfully!
# Content length: 4490 characters

# %%
# Create summarization task
summarize_task = Task(
  description=f"""Summarize the following blog post about AI trends in exactly 30-40 lines.
  Focus on the key points, main trends, and important insights. Make it concise but comprehensive.
  
  Blog post content:
  {blog_content}
  
  Create a well-structured summary that captures:
  1. The main theme and introduction
  2. Key AI trends discussed
  3. Practical implications for readers
  4. Future outlook and conclusion""",
  expected_output='A comprehensive 30-40 line summary of the AI trends blog post, well-formatted and easy to read.',
  agent=summarizer
)

# %%
# Create and run the summarization crew
summarization_crew = Crew(
  agents=[summarizer],
  tasks=[summarize_task],
  process=Process.sequential,
  verbose=True
)

# Execute the summarization
summary_result = summarization_crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 0fd85b1a-4f38-4fba-bdd9-7583fffde4e9                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ...

# %%
# Save the summary to a markdown file
summary_filename = "ai_trends_summary.md"

with open(summary_filename, 'w', encoding='utf-8') as file:
    file.write(summary_result.raw)

print(f"\n✅ Summary successfully saved to {summary_filename}")
print(f"Summary length: {len(summary_result.raw)} characters")
print("\n" + "="*50)
print("SUMMARY PREVIEW:")
print("="*50)
print(summary_result.raw)
# Out:
# ✅ Summary successfully saved to ai_trends_summary.md
# Summary length: 3102 characters
#
# ...
# SUMMARY PREVIEW:
# ...
# Artificial intelligence (AI) has rapidly transitioned from a futuristic concept to a transformative force, profoundly shaping our daily
# lives and various industries. It is actively revolutionizing creative processes and fostering greater technological inclusivity,
# becoming an indispensable part of our existence. To truly grasp AI's trajectory, it's essential to understand the pivotal trends
# driving its accelerated evolution.
#
# One of the most impactful and widely discussed trends is **Generative AI**, which empowers systems to create entirely new content
# from scratch. This encompasses generating compelling text, stunning visual imagery, original musical compositions, and even video
# – often so sophisticated it's indistinguishable from human-produced work. For users, Generative AI serves as an invaluable assistant,
# ...
